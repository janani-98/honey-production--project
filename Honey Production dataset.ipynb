# %% [markdown]
# # Course 2: Python Project 04

# %% [markdown]
# # JANANI L

# %% [markdown]
# # GREAT LEARNING CAREER ACADEMY

# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# # Domain: Food and agriculture

# %% [markdown]
# Objective: The Goal is to use Python visualization libraries such as seaborn and matplotlib to investigate the data and get some useful conclusions.

# %% [markdown]
# ### 1. Import required libraries and read the dataset.

# %%
#Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the dataset
data = pd.read_csv('honeyproduction.csv')

# %% [markdown]
# ### 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
# Display the first few samples
print(data.head())
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
# Check the shape of the data
print(data.shape)
# Out:
# (626, 8)

# %%
# Get information about the data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB
# None

# %% [markdown]
# ### 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
# Group the data by 'year' and calculate the sum of production value for each year
yearly_production = data.groupby('year')['prodvalue'].sum()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(yearly_production, labels=yearly_production.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage Distribution of Production Value by Year')
plt.show()

# %% [markdown]
# ### 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data['priceperlb'], kde=True)
plt.title('Distribution of Price per lb')
plt.show()

# %% [markdown]
# Findings: The histogram shows the distribution of the 'price per lb' variable. You can observe the frequency of different price ranges in the dataset.

# %% [markdown]
# ### 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(data=data, x='numcol', y='prodvalue')
plt.title('Relationship between Number of Colonies and Production Value')
plt.show()

# %% [markdown]
# Findings: The scatterplot shows the relationship between the number of colonies and the production value. It helps us understand how the two variables are related.

# %% [markdown]
# ### 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
# Plot the boxplot between 'year' and 'prodvalue'
sns.boxplot(data=data, x='year', y='prodvalue')
plt.title('Relationship between Year and Production Value')
plt.show()

# %% [markdown]
# Findings: The boxplot displays the distribution of production values for each year. It helps us identify any potential trends or outliers across different years.

# %% [markdown]
# ### 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
# Select the required columns for the pairplot
selected_columns = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year']

# Plot the pairplot
sns.pairplot(data=data[selected_columns], hue='year')
plt.title('Pairplot of Selected Variables with Year-wise Coloring')
plt.show()

# %% [markdown]
# As the number of colonies increases, the production value, yeildpercol and totalproduction increases.

# %% [markdown]
# ### 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
# Select the columns for which we want to calculate correlations
selected_columns = ['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']

# Calculate the correlation matrix
correlation_matrix = data[selected_columns].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The heatmap displays the correlation values between selected numerical variables. It helps us understand the strength and direction of the relationships between the variables. Positive values indicate a positive correlation, while negative values indicate a negative correlation.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# Data Visualization on Honey Production dataset using seaborn and matplotlib libraries was done.
